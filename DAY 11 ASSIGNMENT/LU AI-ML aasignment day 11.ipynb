# %%
import pandas as pd
dataset=pd.read_csv("general_data.csv")
dataset
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
dataset.Attrition=dataset.Attrition.map({"Yes":1,"No":0})
dataset.Gender=dataset.Gender.map({"Male":1,"Female":0})
dataset
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 0      51          0      Travel_Rarely                   Sales
# 1      31          1  Travel_Frequently  Research & Development
# 2      32          0  Travel_Frequently  Research & Development
# 3      38          0         Non-Travel  Research & Development
# 4      32          0      Travel_Rarely  Research & Development
# ...   ...        ...                ...                     ...
# 4405   42          0      Travel_Rarely  Research & Development
# 4406   29          0      Travel_Rarely  Research & Development
# 4407   25          0      Travel_Rarely  Research & Development
# 4408   42          0      Travel_Rarely                   Sales
# 4409   40          0      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
dataset.head()
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 1   31          1  Travel_Frequently  Research & Development
# 2   32          0  Travel_Frequently  Research & Development
# 3   38          0         Non-Travel  Research & Development
# 4   32          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                 6          2  Life Sciences              1           1
# 1                10          1  Life Sciences              1           2
# 2                17          4          Other              1           3
# 3                 2          5  Life Sciences              1           4
# 4                10          1        Medical              1           5
#
#    Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0       0  ...                 1.0      Y                11              8
# ...

# %%
dataset.corr()
# Out:
#                               Age  Attrition  DistanceFromHome  Education  \
# Age                      1.000000  -0.159205          0.006963  -0.035706
# Attrition               -0.159205   1.000000         -0.009730  -0.015111
# DistanceFromHome         0.006963  -0.009730          1.000000  -0.008638
# Education               -0.035706  -0.015111         -0.008638   1.000000
# EmployeeCount                 NaN        NaN               NaN        NaN
# EmployeeID               0.008649  -0.004729         -0.001097  -0.009680
# Gender                  -0.039352   0.018125         -0.044173  -0.016547
# JobLevel                -0.002884  -0.010290         -0.037329   0.045746
# MonthlyIncome           -0.044314  -0.031176         -0.021607   0.006410
# NumCompaniesWorked       0.299243   0.042345         -0.013843  -0.016250
# PercentSalaryHike       -0.033137   0.032533          0.038125  -0.040531
# StandardHours                 NaN        NaN               NaN        NaN
# ...

# %% [markdown]
# # 1. correlation between attrition and distance from home

# %%
from scipy.stats import pearsonr
stats,p=pearsonr(dataset.Attrition,dataset.DistanceFromHome)
print("correllation between Attrition and distanceFromHome is",stats,"and p value is",p)
if(p<0.05):
    print("reject null hypotesis")
else:
    print("accept null hypothesis")
# Out:
# correllation between Attrition and distanceFromHome is -0.009730141010179438 and p value is 0.5182860428049617
# accept null hypothesis

# %% [markdown]
# p>0.05,So Ho is accepted, DistanceFromHome is negatively correlated with Attrition rate

# %% [markdown]
# # 2. correlation between attrition and education

# %%
from scipy.stats import pearsonr
stats,p=pearsonr(dataset.Attrition,dataset.Education)
print("correllation between Attrition and education is",stats,"and p value is",p)
if(p<0.05):
    print("reject null hypotesis")
else:
    print("accept null hypothesis")
# Out:
# correllation between Attrition and education is -0.015111167710968737 and p value is 0.3157293177118575
# accept null hypothesis

# %% [markdown]
# p<0.05,So Ho is rejected, Age is not correlated with the Attrition rate

# %% [markdown]
# # 3.correlation between attrition and employee id

# %%
from scipy.stats import pearsonr
stats,p=pearsonr(dataset.Attrition,dataset.EmployeeID)
print("correllation between Attrition and education is",stats,"and p value is",p)
if(p<0.05):
    print("reject null hypotesis")
else:
    print("accept null hypothesis")
# Out:
# correllation between Attrition and education is -0.004729122995065952 and p value is 0.7535487401882808
# accept null hypothesis

# %% [markdown]
# p>=0.05,So Ho is accepted, EmployeeID is negavively correlated with attrition

# %% [markdown]
# # 4. correlation between attrition and percent salary hike

# %%
from scipy.stats import pearsonr
stats,p=pearsonr(dataset.Attrition,dataset.PercentSalaryHike)
print("correllation between Attrition and PercentSalaryHike is",stats,"and p value is",p)
    
if(p<0.05):
    print("reject null hypotesis")
else:
    print("accept null hypothesis")
# Out:
# correllation between Attrition and PercentSalaryHike is 0.032532594891052195 and p value is 0.030743386433369824
# reject null hypotesis

# %% [markdown]
# p<0.05,So Ho is rejected, Percent Salary Hike is not correlated with Artrition rate

# %% [markdown]
# # 5.correlation between attrition and stock option level

# %%
from scipy.stats import pearsonr
stats,p=pearsonr(dataset.Attrition,dataset.StockOptionLevel)
print("correllation between Attrition and StockOptionLevel is",stats,"and p value is",p)

if(p<0.05):
    print("reject null hypotesis")
else:
    print("accept null hypothesis")
# Out:
# correllation between Attrition and StockOptionLevel is -0.006838852403261021 and p value is 0.6498072937477383
# accept null hypothesis

# %% [markdown]
# p>0.05,So Ho is accepted, StockOptionLevel has correlated with artrition rate

# %% [markdown]
# # 6.correlation between attrition and years with curr manager

# %%
from scipy.stats import pearsonr
stats,p=pearsonr(dataset.Attrition,dataset.YearsWithCurrManager)
print("correllation between Attrition and YearsWithCurrManager is",stats,"and p value is",p)

if(p<0.05):
    print("reject null hypotesis")
else:
    print("accept null hypothesis")
# Out:
# correllation between Attrition and YearsWithCurrManager is -0.15619931590162422 and p value is 1.7339322652951965e-25
# reject null hypotesis

# %% [markdown]
# p<0.05,So Ho is rejected, YearsWithCurrManager is not correlated with the attrition rate

# %% [markdown]
# # 7.correlation between attrition and years at company

# %%
from scipy.stats import pearsonr
stats,p=pearsonr(dataset.Attrition,dataset.YearsAtCompany)
print("correllation between Attrition and YearsAtCompany is",stats,"and p value is",p)

if(p<0.05):
    print("reject null hypotesis")
else:
    print("accept null hypothesis")
# Out:
# correllation between Attrition and YearsAtCompany is -0.13439221398997386 and p value is 3.163883122493571e-19
# reject null hypotesis

# %% [markdown]
# p<0.05,So Ho is rejected, Yearsatcompany is not correlated with the Attrition rate

# %% [markdown]
# # 8.Corrrelation between Attrition and TrainingTimesLastYear

# %%
from scipy.stats import pearsonr
stats,p=pearsonr(dataset.Attrition,dataset.TrainingTimesLastYear)
print("correllation between Attrition and TrainingTimesLastYear is",stats,"and p value is",p)

if(p<0.05):
    print("reject null hypotesis")
else:
    print("accept null hypothesis")
# Out:
# correllation between Attrition and TrainingTimesLastYear is -0.049430576244253066 and p value is 0.001024706191536548
# reject null hypotesis

# %% [markdown]
# p<0.05,So Ho is rejected, TrainingTimeLastyear is not correlated with the Attrition rate

# %% [markdown]
# # 9.correlation between attrition and gender

# %%
from scipy.stats import pearsonr
stats,p=pearsonr(dataset.Attrition,dataset.Gender)
print("correllation between Attrition and Gender is",stats,"and p value is",p)    
if(p<0.05):
    print("reject null hypotesis")
else:
    print("accept null hypothesis")
# Out:
# correllation between Attrition and Gender is 0.01812507887701033 and p value is 0.22881970951790567
# accept null hypothesis

# %% [markdown]
# p>0.05,So Ho is accepted Gender is correlated with Attrition rate

# %% [markdown]
# # 10.correlation with attrition and age

# %%
from scipy.stats import pearsonr
stats,p=pearsonr(dataset.Attrition,dataset.Age)
print("correllation between Attrition and Gender is",stats,"and p value is",p)    
if(p<0.05):
    print("reject null hypotesis")
else:
    print("accept null hypothesis")
# Out:
# correllation between Attrition and Gender is -0.15920500686577505 and p value is 1.996801615893171e-26
# reject null hypotesis

# %% [markdown]
# p<0.05,So Ho is rejected, Age is not correlated with the Attrition rate
